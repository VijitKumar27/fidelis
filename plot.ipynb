# %%
import matplotlib.pyplot as plt
import pandas as pd
import csv

# data.plot(x=str(headers[2:0].keys()),y=headers[2:],kind="bar")
# data.plot(data['District'])
# Out:
# ['States/UTs', 'District', 'Murder', 'Rape_total', 'Kidnapping & Abduction_Total', 'Dacoity_total', 'Robbery', 'Criminal Trespass/Burglary', 'Theft', 'Unlawful Assembly', 'Riots', 'Cheating', 'Forgery', 'Counterfeit_Total', 'Arson', 'Grievous Hurt', 'Dowry Deaths', 'Assault on Women with intent to outrage her Modesty', 'Sexual Harassment', 'Stalking', 'Importation of Girls from Foreign Country', 'Disclosure of Identity of Victims', 'Incidence of Rash Driving', 'HumanTrafficking', 'Total Cognizable IPC crimes']
# 0    Bengaluru City
# Name: District, dtype: object

# %%
with open('abc.csv', 'r') as f:
    d_reader = csv.DictReader(f)

    #get fieldnames from DictReader object and store in list
    headers = d_reader.fieldnames
print(headers)
# Out:
# ['States/UTs', 'District', 'Murder', 'Rape_total', 'Kidnapping & Abduction_Total', 'Dacoity_total', 'Robbery', 'Criminal Trespass/Burglary', 'Theft', 'Unlawful Assembly', 'Riots', 'Cheating', 'Forgery', 'Counterfeit_Total', 'Arson', 'Grievous Hurt', 'Dowry Deaths', 'Assault on Women with intent to outrage her Modesty', 'Sexual Harassment', 'Stalking', 'Importation of Girls from Foreign Country', 'Disclosure of Identity of Victims', 'Incidence of Rash Driving', 'HumanTrafficking', 'Total Cognizable IPC crimes']

# %%
data = pd.read_csv("abc.csv")
values=[]
cnt=2
for i in headers[2:]:
    values.append(data[headers[cnt]][0])
    cnt=cnt+1
print(values)
# Out:
# [241, 312, 708, 449, 1067, 1542, 11455, 0, 388, 3045, 43, 87, 100, 217, 57, 680, 53, 19, 0, 0, 4315, 12, 31892]

# %%
res = {}
for (key,val) in list(zip(headers[2:],values)):
    res[key] = val  
    
res
# Out:
# {'Murder': 241,
#  'Rape_total': 312,
#  'Kidnapping & Abduction_Total': 708,
#  'Dacoity_total': 449,
#  'Robbery': 1067,
#  'Criminal Trespass/Burglary': 1542,
#  'Theft': 11455,
#  'Unlawful Assembly': 0,
#  'Riots': 388,
#  'Cheating': 3045,
#  'Forgery': 43,
#  'Counterfeit_Total': 87,
#  'Arson': 100,
#  'Grievous Hurt': 217,
#  'Dowry Deaths': 57,
#  'Assault on Women with intent to outrage her Modesty': 680,
#  'Sexual Harassment': 53,
#  'Stalking': 19,
#  'Importation of Girls from Foreign Country': 0,
#  'Disclosure of Identity of Victims': 0,
#  'Incidence of Rash Driving': 4315,
#  'HumanTrafficking': 12,
#  'Total Cognizable IPC crimes': 31892}

# %%
lists = sorted(res.items()) # sorted by key, return a list of tuples

x, y = zip(*lists) # unpack a list of pairs into two tuples

plt.plot(x, y,type=plt.bar)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_30600/927284138.py in <module>
#       3 x, y = zip(*lists) # unpack a list of pairs into two tuples
#       4
# ----> 5 plt.plot(x, y,type=plt.bar)
#       6 plt.show()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.plot)
#    3018 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 3019     return gca().plot(
#    3020         *args, scalex=scalex, scaley=scaley,
#    3021         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
#    1604         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1605         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1606         for line in lines:
#    1607             self.add_line(line)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     313                 this += args[0],
#     314                 args = args[1:]
# --> 315             yield from self._plot_args(this, kwargs)
#     316
#     317     def get_next_color(self):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     537             return list(result)
#     538         else:
# --> 539             return [l[0] for l in result]
#     540
#     541
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\axes\_base.py in <listcomp>(.0)
#     537             return list(result)
#     538         else:
# --> 539             return [l[0] for l in result]
#     540
#     541
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\axes\_base.py in <genexpr>(.0)
#     530             labels = [label] * n_datasets
#     531
# --> 532         result = (make_artist(x[:, j % ncx], y[:, j % ncy], kw,
#     533                               {**kwargs, 'label': label})
#     534                   for j, label in enumerate(labels))
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\axes\_base.py in _makeline(self, x, y, kw, kwargs)
#     352         default_dict = self._getdefaults(set(), kw)
#     353         self._setdefaults(default_dict, kw)
# --> 354         seg = mlines.Line2D(x, y, **kw)
#     355         return seg, kw
#     356
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     395         # update kwargs before updating data to give the caller a
#     396         # chance to init axes (and hence unit support)
# --> 397         self.update(kwargs)
#     398         self.pickradius = pickradius
#     399         self.ind_offset = 0
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\artist.py in update(self, props)
#    1060                     func = getattr(self, f"set_{k}", None)
#    1061                     if not callable(func):
# -> 1062                         raise AttributeError(f"{type(self).__name__!r} object "
#    1063                                              f"has no property {k!r}")
#    1064                     ret.append(func(v))
#
# AttributeError: 'Line2D' object has no property 'type'

# %%
fig, ax = plt.subplots(figsize=(50, 20))

# Create bar plot
ax.bar(headers[2:], 
       values)
# Out:
# <BarContainer object of 23 artists>
